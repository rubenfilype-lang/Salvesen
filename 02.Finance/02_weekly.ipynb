# %%
import pandas as pd
import os
import glob

PASTA_FICHEIROS = r"C:\Users\LISARR\Documents\python\01.Financeiro\weekly"
COLUNA_ORIGEM = "ficheiro_origem"
CAMPO_DATA = "FENTREGA"

ficheiros_xls = glob.glob(os.path.join(PASTA_FICHEIROS, "*.xls"))
print(f"Encontrados {len(ficheiros_xls)} ficheiros")

lista_dfs = []

for ficheiro in ficheiros_xls:
    try:
        df_temp = pd.read_excel(ficheiro, engine='xlrd')  # Força o engine xlrd
        df_temp[COLUNA_ORIGEM] = os.path.basename(ficheiro)
        lista_dfs.append(df_temp)
        print(f"  ✓ {os.path.basename(ficheiro)}: {len(df_temp)} linhas")
    except Exception as e:
        print(f"  ✗ Erro ao ler {os.path.basename(ficheiro)}: {e}")

if lista_dfs:
    df = pd.concat(lista_dfs, ignore_index=True)
    df[CAMPO_DATA] = pd.to_datetime(df[CAMPO_DATA], errors='coerce')
    print(f"\n✓ DataFrame criado: {df.shape[0]} linhas, {df.shape[1]} colunas")
    df.head()
# Out:
# Encontrados 1 ficheiros
#   ✗ Erro ao ler SAL_DAT027 (3).xls: Unsupported format, or corrupt file: Expected BOF record; found b'<?xml ve'

# %%
import xml.etree.ElementTree as ET

def ler_linhas_xml_spreadsheet(caminho_ficheiro):
    """
    Lê um ficheiro no formato SpreadsheetML (Excel XML 2003)
    e devolve (cabecalho, linhas)
    """
    tree = ET.parse(caminho_ficheiro)
    root = tree.getroot()
    
    worksheet = root.find('.//{urn:schemas-microsoft-com:office:spreadsheet}Worksheet')
    table = worksheet.find('{urn:schemas-microsoft-com:office:spreadsheet}Table')
    
    rows = table.findall('{urn:schemas-microsoft-com:office:spreadsheet}Row')
    
    todas_linhas = []
    for row in rows:
        cells = row.findall('{urn:schemas-microsoft-com:office:spreadsheet}Cell')
        linha = []
        for cell in cells:
            data = cell.find('{urn:schemas-microsoft-com:office:spreadsheet}Data')
            valor = data.text if data is not None else ""
            linha.append(valor)
        todas_linhas.append(linha)
    
    if not todas_linhas:
        return None, None
    
    cabecalho = todas_linhas[0]
    linhas = todas_linhas[1:]
    
    return cabecalho, linhas

# %%
# ==============================================================================
# LEITURA DE FICHEIROS PARA DATAFRAME
# ==============================================================================

import glob

ficheiros_xls = glob.glob(os.path.join(PASTA_FICHEIROS, "*.xls"))
print(f"Encontrados {len(ficheiros_xls)} ficheiros")

lista_dfs = []

for ficheiro in ficheiros_xls:
    cabecalho, linhas = ler_linhas_xml_spreadsheet(ficheiro)
    
    if cabecalho and linhas:
        df_temp = pd.DataFrame(linhas, columns=cabecalho)
        df_temp[COLUNA_ORIGEM] = os.path.basename(ficheiro)
        lista_dfs.append(df_temp)
        print(f"  ✓ {os.path.basename(ficheiro)}: {len(df_temp)} linhas")

if lista_dfs:
    df = pd.concat(lista_dfs, ignore_index=True)
    df[CAMPO_DATA] = pd.to_datetime(df[CAMPO_DATA], errors='coerce')
    print(f"\n✓ DataFrame criado: {df.shape[0]} linhas, {df.shape[1]} colunas")
    df.head()
else:
    print("Nenhum ficheiro foi carregado")
# Out:
# Encontrados 1 ficheiros
#   ✓ SAL_DAT027 (3).xls: 65534 linhas
#
# ✓ DataFrame criado: 65534 linhas, 57 colunas

# %%
# ==============================================================================
# FILTROS: PROPIETARIO (CEP, PTG) + MÊS (FENTREGA)
# ==============================================================================

MES_FILTRO = 8  # <-- define aqui o mês desejado (1-12)

df_filtrado = df[
    (df["PROPIETARIO"].isin(["CEP", "PTG"])) &
    (df[CAMPO_DATA].dt.month == MES_FILTRO)
]

print(f"Linhas antes do filtro: {len(df)}")
print(f"Linhas depois do filtro: {len(df_filtrado)}")

df_filtrado.head()
# Out:
# Linhas antes do filtro: 65534
# Linhas depois do filtro: 8568
#       PROPIETARIO                                           TRAYECTO  \
# 16320         CEP  SALVESEN LOGISTICA PORTUGAL / AUCHAN RETAIL PO...
# 16321         CEP  SALVESEN LOGISTICA PORTUGAL / AUCHAN RETAIL PO...
# 16322         CEP  SALVESEN LOGISTICA PORTUGAL / AUCHAN RETAIL PO...
# 16323         PTG  SALVESEN LOGISTICA PORTUGAL / AUCHAN RETAIL PO...
# 16324         PTG  SALVESEN LOGISTICA PORTUGAL / AUCHAN RETAIL PO...
#
#       TRANSPORTISTA TRACTORA REMOLQUE INGRESODT COSTEDT RENTADT PALETSDT  \
# 16320      SALVESEN  0002HGS  0002HGS     15.79       0   15.79     2.36
# 16321      SALVESEN  0002HGS  0002HGS      0.49       0    0.49      0.1
# 16322      SALVESEN  0002HGS  0002HGS     67.92       0   67.92        8
# 16323      SALVESEN  0002HGS  0002HGS     14.16       0   14.16     2.32
# 16324      SALVESEN  0002HGS  0002HGS       7.3       0     7.3        1
#
#       PESO_BRUTO  ...  LOCDES                    LUGARDESCARGA TEMP_MERC_PED  \
# 16320    1227.17  ...  706584                AUCHAN - AZAMBUJA        RFGRFG
# 16321      37.44  ...  706584                AUCHAN - AZAMBUJA        RFGRFG
# 16322    1338.67  ...  746383  AUCHAN - SALVESEN - REFRIGERADO           TAM
# 16323      646.5  ...  527060           AUCHAN RETAIL PORTUGAL        RFGRFG
# 16324        501  ...  727278                  AUCHAN SALVESEN           @@@
#
#       TIPOPALETA      CAMION_TIPO CAMION_CAPACIDAD TIPO_COMBUSTIBLE KMREALES  \
# 16320        EUR  Trailer 33 plts               33           DIESEL        0
# 16321        EUR  Trailer 33 plts               33           DIESEL        0
# 16322        EUR  Trailer 33 plts               33           DIESEL        0
# 16323        EUR  Trailer 33 plts               33           DIESEL    55.48
# 16324        EUR  Trailer 33 plts               33           DIESEL        0
#
#       ALBARAN     ficheiro_origem
# 16320      NO  SAL_DAT027 (3).xls
# 16321      NO  SAL_DAT027 (3).xls
# 16322      NO  SAL_DAT027 (3).xls
# 16323      NO  SAL_DAT027 (3).xls
# 16324      NO  SAL_DAT027 (3).xls
#
# [5 rows x 57 columns]

# %%
# ==============================================================================
# RESUMO POR FENTREGA: CUSTO, PALETS, CUSTO/PALETE
# ==============================================================================

df_filtrado["COSTEDT"] = (
    df_filtrado["COSTEDT"].astype(str).str.replace(",", ".").astype(float)
)
df_filtrado["PALETS"] = (
    df_filtrado["PALETS"].astype(str).str.replace(",", ".").astype(float)
)

resumo_dia = df_filtrado.groupby(CAMPO_DATA).agg(
    CUSTO=("COSTEDT", "sum"),
    PALETS=("PALETS", "sum")
).reset_index()

resumo_dia["CUSTO_POR_PALETE"] = resumo_dia["CUSTO"] / resumo_dia["PALETS"]

resumo_dia["CUSTO"] = resumo_dia["CUSTO"].apply(lambda x: f"{x:,.0f}".replace(",", "."))

resumo_dia
# Out:
#      FENTREGA   CUSTO  PALETS  CUSTO_POR_PALETE
# 0  2026-08-01  10.437   899.0         11.609655
# 1  2026-08-03  20.919  1812.0         11.544917
# 2  2026-08-04  22.099  1982.0         11.149823
# 3  2026-08-05  23.652  2461.0          9.610825
# 4  2026-08-06  21.808  2226.0          9.797075
# 5  2026-08-07  24.035  2523.0          9.526243
# 6  2026-08-08  10.089   966.0         10.444089
# 7  2026-08-10  20.983  1866.0         11.244818
# 8  2026-08-11  22.429  2328.0          9.634356
# 9  2026-08-12  25.426  2612.0          9.734387
# 10 2026-08-13  20.328  1884.0         10.789830
# 11 2026-08-14  24.230  2814.0          8.610629
# 12 2026-08-15  10.425   936.0         11.137959
# 13 2026-08-17  18.595  1849.0         10.056804
# 14 2026-08-18   1.028    46.0         22.345000

# %%
# ==============================================================================
# FILTROS: PROPIETARIO (CEP, PTG) + MÊS + GRAVAR ATÉ AO DIA ESCOLHIDO
# ==============================================================================

MES_FILTRO = 8   # <-- define o mês (1-12)
DIA_FIM = 15     # <-- define o dia final do período

CAMINHO_CSV = r"C:\Users\LISARR\Documents\Infor_27_weekly\SAL_DAT027.csv"

df_filtrado = df[
    (df["PROPIETARIO"].isin(["CEP", "PTG"])) &
    (df[CAMPO_DATA].dt.month == MES_FILTRO)
]

data_fim = df_filtrado[CAMPO_DATA].dt.to_period("M").iloc[0].start_time.replace(day=DIA_FIM)
df_periodo = df_filtrado[df_filtrado[CAMPO_DATA] <= data_fim]

for col in ["INGRESODT", "COSTEDT", "RENTADT"]:
    df_periodo[col] = (
        df_periodo[col].astype(str).str.replace(",", ".").astype(float)
    )

df_periodo.to_csv(CAMINHO_CSV, index=False, sep=";", encoding="utf-8-sig", date_format="%Y%m%d")

print(f"✓ Mês: {MES_FILTRO} | Até dia: {DIA_FIM}")
print(f"✓ Linhas gravadas: {len(df_periodo)}")
print(f"✓ Ficheiro gravado: {CAMINHO_CSV}")
# Out:
# ✓ Mês: 8 | Até dia: 15
# ✓ Linhas gravadas: 7622
# ✓ Ficheiro gravado: C:\Users\LISARR\Documents\Infor_27_weekly\SAL_DAT027.csv

# %%
# ==============================================================================
# RESUMO POR PRESTADOR (TRANSPORTISTA) - SELECIONAR DIA
# ==============================================================================

DIA_SELECIONADO = 11  # <-- define aqui o dia do mês (ex: 8)

df_dia = df_filtrado[df_filtrado[CAMPO_DATA].dt.day == DIA_SELECIONADO].copy()

df_dia["COSTEDT"] = df_dia["COSTEDT"].astype(str).str.replace(",", ".").astype(float)
df_dia["PALETS"] = df_dia["PALETS"].astype(str).str.replace(",", ".").astype(float)

resumo_prestador = df_dia.groupby("TRANSPORTISTA").agg(
    CUSTO=("COSTEDT", "sum"),
    PALETS=("PALETS", "sum")
).reset_index()

resumo_prestador["CUSTO_POR_PALETE"] = resumo_prestador["CUSTO"] / resumo_prestador["PALETS"]

resumo_prestador["CUSTO"] = resumo_prestador["CUSTO"].apply(lambda x: f"{x:,.0f}".replace(",", "."))

resumo_prestador
# Out:
#                                         TRANSPORTISTA  CUSTO  PALETS  \
# 0                  CMTIR TRANSPORTES NAC. INTERN. S.A  2.633   155.0
# 1           J. MARCOS FABIO E SEATLLE TRANSPORTES LDA    310     9.0
# 2    JMR PRESTAÇAO DE SERVIÇOS PARA A DISTRIBUÇAO S.A  3.202   458.0
# 3                MODELO CONTINENTE HIPERMERCADOS S.A.    780    99.0
# 4                           RAMITRANS TRANSPORTES LDA    727    64.0
# 5                                            SALVESEN      0    92.0
# 6                                          TIERS SPOT      0     1.0
# 7              TJA-TRANSPORTES J.AMARAL, S.A.       -    981    90.0
# 8   TORRESTIR - TRANSPORTES NACIONAIS E INTERNACIO...  1.000    47.0
# 9                           TRANSAURA TRANSPORTES LDA    868   125.0
# 10           TRANSBASE - TRANSPORTES E LOGISTICA S.A.    153    23.0
# 11  TRANSPARENTODISSEIA - Transportes Unipessoal, ...  1.111    97.0
# 12           TRANSPORTES FIGUEIREDO & FIGUEIREDO, LDA    186     4.0
# 13               TRANSPORTES FLORENCIO SILVA, LDA.  -  6.956   732.0
# 14                   TRANSPORTES MACHADO & BRITES LDA    790    25.0
# 15             TRANSPORTES PAULO COSTA & FERREIRA LDA    823   100.0
# 16     Transportes Fernando Simões Monteiro Unip. Lda  1.552   149.0
# 17                       WORLD RUNNERS UNIPESSOAL LDA    358    58.0
#
#     CUSTO_POR_PALETE
# 0          16.985097
# 1          34.446667
# 2           6.991441
# 3           7.877576
# 4          11.359687
# 5           0.000000
# 6           0.000000
# 7          10.898333
# 8          21.276383
# 9           6.943680
# 10          6.637391
# 11         11.458660
# 12         46.537500
# 13          9.502582
# 14         31.584000
# 15          8.229700
# 16         10.412953
# 17          6.172414

# %%
# ==============================================================================
# DETALHE POR DIA + TRANSPORTADOR: CODEUT, PALETS, CUSTO, ORIGEM, DESTINO
# ==============================================================================

DIA_SELECIONADO = 10  # <-- define aqui o dia do mês
TRANSPORTADOR_SELECIONADO = "TRANSPORTES FIGUEIREDO & FIGUEIREDO, LDA"  # <-- define aqui o transportador

df_detalhe = df_filtrado[
    (df_filtrado[CAMPO_DATA].dt.day == DIA_SELECIONADO) &
    (df_filtrado["TRANSPORTISTA"] == TRANSPORTADOR_SELECIONADO)
]

detalhe = df_detalhe[["CODEUT", "PALETS", "COSTEDT", "LUGARCARGA", "LUGARDESCARGA"]].copy()
detalhe["COSTEDT"] = detalhe["COSTEDT"].astype(str).str.replace(",", ".").astype(float)
detalhe["COSTEDT"] = detalhe["COSTEDT"].apply(lambda x: f"{x:,.0f}".replace(",", "."))

detalhe
# Out:
#         CODEUT PALETS COSTEDT                     LUGARCARGA  \
# 39718  3515746      2      77          AUCHAN CASTELO BRANCO
# 39719  3515746      1      39          AUCHAN CASTELO BRANCO
# 39720  3515746      3     116  CONFEITARIA CARLOS GONÇALVES,
# 39721  3515746      1       1  SALVESEN LOGISTICA AZAMBUJA 2
# 39722  3515746      7     249    SALVESEN LOGISTICA PORTUGAL
# 39723  3515746      1      20  SALVESEN LOGISTICA AZAMBUJA 2
# 39724  3515746      1      17    SALVESEN LOGISTICA PORTUGAL
# 39725  3515746      1       3    SALVESEN LOGISTICA PORTUGAL
# 39726  3515746      1       3    SALVESEN LOGISTICA PORTUGAL
# 39727  3515746      1       0    SALVESEN LOGISTICA PORTUGAL
# 41945  3516439      1      28  SALVESEN LOGISTICA AZAMBUJA 2
# 41946  3516439      8     534    SALVESEN LOGISTICA PORTUGAL
# 41947  3516439      1      52  SALVESEN LOGISTICA AZAMBUJA 2
# 41948  3516439      1       4  SALVESEN LOGISTICA AZAMBUJA 2
# 41949  3516439      1       2  SALVESEN LOGISTICA AZAMBUJA 2
# 41950  3516439      2      83    SALVESEN LOGISTICA PORTUGAL
#
#                          LUGARDESCARGA
# 39718      SALVESEN LOGISTICA PORTUGAL
# 39719      SALVESEN LOGISTICA PORTUGAL
# 39720      LIDL BELGIUM GMBH UND CO.KG
# 39721   DANIGURTE DIST. PRODUTOS ALIME
# 39722                        DANIGURTE
# 39723                        DANIGURTE
# 39724            AUCHAN CASTELO BRANCO
# 39725   A.S VILA VELHA RODAO I (11548)
# 39726  A.S VILA VELHA RODAO II (11545)
# 39727      A.S. VILA VELHA RÓDÃO (S/N)
# 41945                      DISABA, LDA
# 41946                       DISABA,LDA
# 41947                       DISABA,LDA
# 41948                  MANUEL TELES,SA
# 41949     MANUEL TELES,SA (PORTALEGRE)
# 41950     MANUEL TELES,SA (PORTALEGRE)
